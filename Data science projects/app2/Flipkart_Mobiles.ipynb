# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv("Flipkart_Mobiles.csv")

# %%
Mobiles_df=pd.read_csv("Flipkart_Mobiles.csv")
Mobiles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            500 non-null    int64
#  1   Brand           500 non-null    object
#  2   Memory          500 non-null    object
#  3   Storage         500 non-null    object
#  4   Rating          490 non-null    float64
#  5   Selling Price   500 non-null    int64
#  6   Original Price  500 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 27.5+ KB

# %%
def plot(title,plot_func,*args,**kwargs):
    plt.title(title)
    plot_func(*args,**kwargs)
    plt.show()

# %%
plot('visalize Missing Data',sns.heatmap,Mobiles_df.isnull(), cbar=True)

# %%
#Handle missing values in 'Age' columns
Mobiles_df['Rating'].fillna(Mobiles_df['Rating'].median(),inplace=True)

# %%
plot('visalize Missing Data',sns.heatmap,Mobiles_df.isnull(), cbar=True)
